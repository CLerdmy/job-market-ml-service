# %%
import sys
from pathlib import Path

project_root = Path().resolve().parents[0]
sys.path.append(str(project_root))

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from src.models.registry import load_model

model = load_model("salary_predictor")

# %%
from src.data.load import load_prepared_job_market_dataset

df = load_prepared_job_market_dataset()

# %%
from src.models.evaluate import calculate_metrics, calculate_cv_rmse

# %%
df_pd = df.to_pandas()
target = "salary_mean"

X = df_pd.drop(columns=[target])
y = df_pd[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=22
)

# %%
calculate_metrics(model, X_test, y_test)
# Out:
# RMSE: 4905.000456901834
# MAE: 2916.8895670671372
# R2: 0.9711351700396662
# MAPE: 2.7837080475077793
# SMAPE: 2.6650673257222235
# WAPE: 2.3678807801712773

# %%
calculate_cv_rmse(model, X, y)
# Out:
# CV RMSE folds: [7924.24459479 6034.13412849 6552.41355577 6047.07612505 6021.42830383]
# CV RMSE mean: 6515.86
